# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
from scipy.sparse import hstack  
from ast import literal_eval

# %%
df = pd.read_csv("C:\\Users\\20100\\Desktop\\graduation project\\ML Model\\furniture_store - Copy_db.csv",
                 usecols=["product_id","product_category","product_name","product_description"])
# df = pd.read_csv("C:\\Users\\20100\\Desktop\\graduation project\\ML Model\\roveconcepts2.csv",
#                  usecols=["product_category","product_name","product_description"])

# %%
df.head()
# Out:
#    product_id product_category product_name  \
# 0    30180504    Bar furniture      NORBERG
# 1    10122647    Bar furniture       INGOLF
# 2    70404875    Bar furniture     FRANKLIN
# 3    50406465    Bar furniture     FRANKLIN
# 4    90404879    Bar furniture     FRANKLIN
#
#                                  product_description
# 0          Wall-mounted drop-leaf table,         ...
# 1            Bar stool with backrest,          63 cm
# 2          Bar stool with backrest, foldable,    ...
# 3          Bar stool with backrest, foldable,    ...
# 4          Bar stool with backrest, foldable,    ...

# %%
if '30180504' in df['product_id'].astype(str).values:
    print("Value found in DataFrame.")
else:
    print("Value not found in DataFrame.")
# Out:
# Value found in DataFrame.

# %%
print('30180504' in df['product_id'].astype(str).values)
# Out:
# True

# %%
# df['product_id'].dtypet()
# print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22040\357457905.py in <module>
# ----> 1 df['product_id'].dtypet()
#       2 print(df.columns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'dtypet'

# %%
df = df.set_index('product_id')

# %%
df["product_name"].value_counts()
# Out:
# PAX                  101
# BESTÅ                 96
# EKET                  54
# PLATSA                53
# GRÖNLID               52
#                     ...
# TERJE                  1
# EKENÄS                 1
# SVENARNE               1
# FANBYN                 1
# PAX / MEHAMN/AULI      1
# Name: product_name, Length: 288, dtype: int64

# %%
#some of products name is redundant in many categories ,so it is not good to recommend by 'products_name'
# I should use product_id

# %%
# Parse the stringified features into their corresponding python objects
features= "['product_category', 'product_name', 'product_description']"
features_list = ast.literal_eval(features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22040\2835172037.py in <module>
#       1 # Parse the stringified features into their corresponding python objects
#       2 features= "['product_category', 'product_name', 'product_description']"
# ----> 3 features_list = ast.literal_eval(features)
#
# NameError: name 'ast' is not defined

# %%
# Define the product description and category/name vectors
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
count_vectorizer = CountVectorizer(stop_words='english')

product_descriptions = df['product_description']
product_categories = df['product_category']
product_names = df['product_name']

# Create the product description and category/name matrices
tfidf_matrix = tfidf_vectorizer.fit_transform(product_descriptions)
count_matrix = count_vectorizer.fit_transform(product_categories + ' ' + product_names)

# Combine the matrices
combined_similarity_matrix = cosine_similarity(hstack([tfidf_matrix, count_matrix]))

# %%
######modify######
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
count_vectorizer = CountVectorizer(stop_words='english')

product_descriptions = df['product_description']
product_categories = df['product_category']
product_names = df['product_name']

tfidf_matrix = tfidf_vectorizer.fit_transform(product_descriptions)

# Apply a weight factor to the count matrix for 'product_category'
category_matrix_weight = 2  # Set the weight factor for 'product_category'
count_matrix_category = count_vectorizer.fit_transform(category_matrix_weight * product_categories)
count_matrix_name = count_vectorizer.fit_transform(product_names)
count_matrix = hstack([count_matrix_category, count_matrix_name])

# Combine the matrices
combined_similarity_matrix = cosine_similarity(hstack([tfidf_matrix, count_matrix]))

# %%
def get_related_products(product_name, num_products=25):
    # Find the index of the input product
    if product_name not in df['product_name'].values:
        print(f"{product_name} not found in product list.")
        return None
    idx = df[df['product_name']==product_name].index[0]

    # Get the cosine similarity scores of all products to the input product
    sim_scores = list(enumerate(combined_similarity_matrix[idx]))

    # Sort the products by their similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the indices of the top num_products similar products
    sim_indices = [i[0] for i in sim_scores[1:num_products+1]]

    # Return the top num_products similar products
    return df.iloc[sim_indices][['product_category', 'product_name', 'product_description']]

related_products = get_related_products('HEMNES')
related_products
# Out:
#        product_category product_name  \
# 35                 Beds       HEMNES
# 41                 Beds       HEMNES
# 48                 Beds      BRIMNES
# 62                 Beds      BRIMNES
# 23                 Beds       PLATSA
# 52                 Beds       PLATSA
# 59                 Beds       PLATSA
# 1239  Sofas & armchairs       HEMNES
# 53                 Beds       PLATSA
# 56                 Beds       PLATSA
# 45                 Beds       PLATSA
# 25                 Beds      BRIMNES
# 27                 Beds      BRIMNES
# 42                 Beds       NORDLI
# 46                 Beds       PLATSA
# 47                 Beds       PLATSA
# 65                 Beds       PLATSA
# 33                 Beds    SONGESAND
# 49                 Beds    SONGESAND
# 50                 Beds        SLÄKT
# 22                 Beds      BRIMNES
# 32                 Beds       NORDLI
# 30                 Beds       PLATSA
# 39                 Beds       ASKEBY
# 57                 Beds    GRÄLVIKEN
#
#                                     product_description
# 35            Day-bed frame with 3 drawers,         ...
# 41            Day-bed w 3 drawers/2 mattresses,     ...
# 48            Day-bed frame with 2 drawers,         ...
# 62            Day-bed w 2 drawers/2 mattresses,     ...
# 23            Bed frame with 4 drawers,          140...
# 52            Bed frame with 2 drawers,          142...
# 59            Bed frame with 4 drawers,          142...
# 1239          Day-bed w 3 drawers/2 mattresses,     ...
# 53            Bed frame with 4 doors+6 drawers,     ...
# 56            Bed frame with 2 door+3 drawers,      ...
# 45            Bed frame with 10 drawers,          14...
# 25            Bed frame with storage,          90x20...
# 27            Bed frame with storage,          140x2...
# 42            Bed frame with storage,          140x2...
# 46            Bed frame with storage,          140x2...
# 47            Bed frame with 6 doors+12 drawers,    ...
# 65            Bed frame with storage,          140x2...
# 33            Bed frame with 2 storage boxes,       ...
# 49            Bed frame with 4 storage boxes,       ...
# 50            Bed frame with 3 storage boxes,       ...
# 22            Bed frame w storage and headboard,    ...
# 32            Bed frame w storage and headboard,    ...
# 30            Bed frame with 10 doors,          143x...
# 39                                    Two-seat sofa-bed
# 57                                      3-seat sofa-bed

# %%
def get_related_products(product_id, num_products=25):
    # Find the index of the input product
    if product_id not in df.index:
        print(f"{product_id} not found in product list.")
        return None
    idx = df.index.get_loc(product_id)

    # Get the cosine similarity scores of all products to the input product
    sim_scores = list(enumerate(combined_similarity_matrix[idx]))

    # Sort the products by their similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the indices of the top num_products similar products
    sim_indices = [i[0] for i in sim_scores[1:num_products+1]]

    # Return the top num_products similar products
    return df.iloc[sim_indices][['product_category', 'product_name', 'product_description']]

related_products = get_related_products('30180504')
related_products
# Out:
# 30180504 not found in product list.

# %%
from scipy.sparse import hstack

# Define the product description and category/name vectors
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
count_vectorizer = CountVectorizer(stop_words='english')

product_descriptions = df['product_description']
product_categories = df['product_category']
product_names = df['product_name']

# Create the product description and category/name matrices
tfidf_matrix = tfidf_vectorizer.fit_transform(product_descriptions)

# Apply a weight factor to the count matrix for 'product_category'
category_matrix_weight = 2  # Set the weight factor for 'product_category'
count_matrix_category = count_vectorizer.fit_transform(category_matrix_weight * product_categories)
count_matrix_name = count_vectorizer.fit_transform(product_names)
count_matrix = hstack([count_matrix_category, count_matrix_name])

# Combine the matrices
combined_similarity_matrix = cosine_similarity(hstack([tfidf_matrix, count_matrix]))

def get_related_products(product_id, num_products=25):
    # Find the index of the input product
    if product_id not in df.index:
        print(f"{product_id} not found in product list.")
        return None
    idx = df.index.get_loc(product_id)

    # Get the cosine similarity scores of all products to the input product
    sim_scores = list(enumerate(combined_similarity_matrix[idx]))

    # Sort the products by their similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the indices of the top num_products similar products
    sim_indices = [i[0] for i in sim_scores[1:num_products+1]]

    # Return the top num_products similar products
    return df.iloc[sim_indices][['product_category', 'product_name', 'product_description']]

related_products = get_related_products(30275861)
related_products
# Out:
#                                 product_category product_name  \
# product_id
# 9017483                            Room dividers       KALLAX
# 70301537                           Room dividers       KALLAX
# 10275862              Bookcases & shelving units       KALLAX
# 89030584              Bookcases & shelving units       KALLAX
# 19030592              Bookcases & shelving units       KALLAX
# 39017486              Bookcases & shelving units       KALLAX
# 19278328              Bookcases & shelving units       KALLAX
# 69017475              Bookcases & shelving units       KALLAX
# 80275887              Bookcases & shelving units       KALLAX
# 70301542              Bookcases & shelving units       KALLAX
# 20275814              Bookcases & shelving units       KALLAX
# 275848                Bookcases & shelving units       KALLAX
# 20409936              Bookcases & shelving units       KALLAX
# 9197436               Bookcases & shelving units       KALLAX
# 99017445              Bookcases & shelving units       KALLAX
# 90301555              Bookcases & shelving units       KALLAX
# 79278269              Bookcases & shelving units       KALLAX
# 59278307              Bookcases & shelving units       KALLAX
# 39278290              Bookcases & shelving units       KALLAX
# 29278262              Bookcases & shelving units       KALLAX
# 79278250              Bookcases & shelving units       KALLAX
# 9278338               Bookcases & shelving units       KALLAX
# 10459903    Sideboards, buffets & console tables       KALLAX
# 19222299              Bookcases & shelving units       KALLAX
# 49133616              Bookcases & shelving units       KALLAX
#
#                                           product_description
# product_id
# 9017483             Shelving unit with 4 inserts,         ...
# 70301537                   Shelving unit,          182x182 cm
# 10275862                   Shelving unit,          147x147 cm
# 89030584            Shelving unit with 4 inserts,         ...
# 19030592            Shelving unit with 8 inserts,         ...
# 39017486            Shelving unit with 4 inserts,         ...
# 19278328            Shelving unit with 4 inserts,         ...
# 69017475            Shelving unit with 8 inserts,         ...
# 80275887                    Shelving unit,          77x147 cm
# 70301542                   Shelving unit,          182x182 cm
# 20275814                     Shelving unit,          77x77 cm
# 275848                      Shelving unit,          42x147 cm
# 20409936                   Shelving unit,          112x147 cm
# 9197436             Shelving unit with doors,          77x...
# 99017445            Shelving unit with doors,          77x...
# 90301555                     Shelving unit,          77x42 cm
# 79278269            Shelving unit with doors,          77x...
# 59278307            Shelving unit with 4 inserts,         ...
# 39278290            Shelving unit with 2 inserts,         ...
# 29278262            Shelving unit with 6 inserts,         ...
# 79278250            Shelving unit with 4 inserts,         ...
# 9278338             Shelving unit with 10 inserts,        ...
# 10459903                    Shelving unit,          77x147 cm
# 19222299             Desk combination,          77x147x159 cm
# 49133616            Desk combination,          147x147x159 cm

# %%
1-First, it checks if the input product_id exists in the index of the DataFrame df.
  If the product_id is not found, the function prints a message and returns None.
2-If the product_id is found, the function gets the index idx of the input product in the DataFrame df.
3-The function then gets the cosine similarity scores between the input product and all other products in the DataFrame df.
  It does this by getting the idx-th row of the combined_similarity_matrix.
3-The similarity scores are then sorted in descending order, so that the most similar products are first.
4-The function then selects the top num_products similar products (excluding the input product itself)
  by getting the indices of the products with the highest similarity scores. 
    These indices are stored in the sim_indices variable.
5-Finally, the function returns a DataFrame containing the product category, name, and description
  of the top num_products similar products, as indexed by sim_indices.

# %%
from scipy.sparse import hstack

# Set 'product_id' as the index of the DataFrame
# /df = df.set_index('product_id')

# Define the product description and category/name vectors
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
count_vectorizer = CountVectorizer(stop_words='english')

product_descriptions = df['product_description']
product_categories = df['product_category']
product_names = df['product_name']

# Create the product description and category/name matrices
tfidf_matrix = tfidf_vectorizer.fit_transform(product_descriptions)

# Apply a weight factor to the count matrix for 'product_category'
category_matrix_weight = 2  # Set the weight factor for 'product_category'
count_matrix_category = count_vectorizer.fit_transform(category_matrix_weight * product_categories)
count_matrix_name = count_vectorizer.fit_transform(product_names)
count_matrix = hstack([count_matrix_category, count_matrix_name])

# Combine the matrices
combined_similarity_matrix = cosine_similarity(hstack([tfidf_matrix, count_matrix]))

def get_related_products(product_name, num_products=25):
    # Find the index of the input product
    idx = df[df['product_name']==product_name].index[0]

    # Get the cosine similarity scores of all products to the input product
    sim_scores = list(enumerate(combined_similarity_matrix[idx]))

    # Sort the products by their similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the indices of the top num_products similar products
    sim_indices = [i[0] for i in sim_scores[1:num_products+1]]

    # Return the top num_products similar products
    return df.iloc[sim_indices][['product_category', 'product_name', 'product_description']]

# Example usage
related_products = get_related_products('NORBERG')
related_products
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22040\845919230.py in <module>
#      41
#      42 # Example usage
# ---> 43 related_products = get_related_products('NORBERG')
#      44 related_products
#
# ~\AppData\Local\Temp\ipykernel_22040\845919230.py in get_related_products(product_name, num_products)
#      29
#      30     # Get the cosine similarity scores of all products to the input product
# ---> 31     sim_scores = list(enumerate(combined_similarity_matrix[idx]))
#      32
#      33     # Sort the products by their similarity scores
#
# IndexError: index 30180504 is out of bounds for axis 0 with size 1593

# %%
from scipy.sparse import hstack

# Set 'product_id' as the index of the DataFrame
# df = df.set_index('product_id')

# Define the product description and category/name vectors
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
count_vectorizer = CountVectorizer(stop_words='english')

product_descriptions = df['product_description']
product_categories = df['product_category']
product_names = df['product_name']

# Create the product description and category/name matrices
tfidf_matrix = tfidf_vectorizer.fit_transform(product_descriptions)

# Apply a weight factor to the count matrix for 'product_category'
category_matrix_weight = 2  # Set the weight factor for 'product_category'
count_matrix_category = count_vectorizer.fit_transform(category_matrix_weight * product_categories)
count_matrix_name = count_vectorizer.fit_transform(product_names)
count_matrix = hstack([count_matrix_category, count_matrix_name])

# Combine the matrices
combined_similarity_matrix = cosine_similarity(hstack([tfidf_matrix, count_matrix]))


# Reset index of our main DataFrame and construct reverse mapping as before
df = df.reset_index()
indices = pd.Series(df.index, index=df['product_id'])

# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title, cosine_sim=combined_similarity_matrix):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df['product_id'].iloc[movie_indices]

# %%
get_recommendations(30180504)
# Out:
# 12    30352246
# 21    30308395
# 10    70246089
# 13    10281354
# 20    30135658
# 5       121766
# 6       397736
# 16    90319918
# 17    39184324
# 18    20429010
# Name: product_id, dtype: int64
