# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


df = pd.read_csv("C:\\Users\\20100\\Desktop\\graduation project\\ML Model\\furniture_store - Copy_db.csv",
                 usecols=["product_category","product_name","product_description"])

# Combine all columns into a single 'content' column
df['content'] = df.apply(lambda row: ' '.join(row), axis=1)
# Cell 3: Train the model

vectorizer = TfidfVectorizer(stop_words='english')
content_matrix = vectorizer.fit_transform(df['content'])

# Compute the cosine similarity matrix
similarity_matrix = cosine_similarity(content_matrix)
# Cell 4: Define the recommendation function

def recommend_products(product_name, n_recommendations=25):
    # Get the index of the product
    product_index = df[df['product_name'] == product_name].index[0]

    # Get the similarity scores of all products with the given product
    product_similarities = list(enumerate(similarity_matrix[product_index]))

    # Sort the products based on similarity scores
    product_similarities = sorted(product_similarities, key=lambda x: x[1], reverse=True)

    # Get the indices of the top-n most similar products (excluding the first one, which is the input product itself)
    top_n_indices = [i[0] for i in product_similarities[1:n_recommendations+1]]

    # Return the top-n most similar products
    return df.iloc[top_n_indices]
#Cell 5: Test the recommendation system

# Replace 'NORBERG' with the product name you want to get recommendations for
product_name = 'LEIFARNE'
n_recommendations = 25

recommended_products = recommend_products(product_name, n_recommendations)
print(f"Top {n_recommendations} recommendations for {product_name}:")
recommended_products
# Out:
# Top 25 recommendations for LEIFARNE:
#        product_category product_name                   product_description  \
# 647      Café furniture     LEIFARNE                   Chair with armrests
# 745              Chairs     LEIFARNE                   Chair with armrests
# 648      Café furniture      JANINGE                   Chair with armrests
# 645      Café furniture   SVENBERTIL                   Chair with armrests
# 681              Chairs     LEIFARNE                                 Chair
# 686              Chairs     LEIFARNE                                 Chair
# 726              Chairs     LEIFARNE                                 Chair
# 761              Chairs     LEIFARNE                                 Chair
# 641      Café furniture      JANINGE                                 Chair
# 644      Café furniture      JANINGE                                 Chair
# 643      Café furniture       YNGVAR                                 Chair
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Replace this with your actual data
df = pd.read_csv("C:\\Users\\20100\\Desktop\\graduation project\\ML Model\\furniture_store - Copy_db.csv",
                 usecols=["product_category","product_name","product_description"])

# Combine all columns into a single 'content' column
df['content'] = df.apply(lambda row: ' '.join(row), axis=1)
# Cell 3: Train the model

vectorizer = TfidfVectorizer(stop_words='english')
content_matrix = vectorizer.fit_transform(df['content'])

# Compute the cosine similarity matrix
similarity_matrix = cosine_similarity(content_matrix)
# Cell 4: Define the recommendation function

def recommend_products(product_id, n_recommendations=25,df=df):
    # Get the index of the product
    indices = pd.Series(df.index, index=df['product_name']).drop_duplicates()
    product_index = indices[product_name]
    ####product_index = df[df['product_name'] == product_id].index[0]

    # Get the similarity scores of all products with the given product
    product_similarities = list(enumerate(similarity_matrix[product_index]))

    # Sort the products based on similarity scores
    product_similarities = sorted(product_similarities, key=lambda x: x[1], reverse=True)

    # Get the indices of the top-n most similar products (excluding the first one, which is the input product itself)
    top_n_indices = [i[0] for i in product_similarities[1:n_recommendations+1]]

    # Return the top-n most similar products
    return df.iloc[top_n_indices]
#Cell 5: Test the recommendation system

# Replace 'NORBERG' with the product name you want to get recommendations for
product_name = 'Louis Outdoor Loveseat'
n_recommendations = 25

recommended_products = recommend_products(product_name, n_recommendations)
print(f"Top {n_recommendations} recommendations for {product_name}:")
recommended_products
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load the product data
df = pd.read_csv("C:\\Users\\20100\\Desktop\\graduation project\\ML Model\\roveconcepts2.csv",
                 usecols=["product_category","product_name","product_description"])

# Define the product description and category/name vectors
tfidf_vectorizer = TfidfVectorizer(stop_words='english')

product_descriptions = df['product_description']
product_categories = df['product_category']
product_names = df['product_name']

# Create the product description and category/name matrices
tfidf_matrix = tfidf_vectorizer.fit_transform(product_descriptions)
combined_matrix = cosine_similarity(hstack([tfidf_matrix, tfidf_matrix])

# Define function to recommend products
def recommend_products(product_name, n_recommendations=5):
    product_index = df[df['product_name'] == product_name].index[0]
    recommended_indices = combined_matrix[product_index].argsort()[:-n_recommendations-1:-1]
    recommended_products = df.iloc[recommended_indices]['product_name']
    return recommended_products

# Get recommendations for a product
product_name = 'Product A'
n_recommendations = 5
recommended_products = recommend_products(product_name, n_recommendations)

# Filter products that are not in the recommended list
is_recommended = df['product_name'].isin(recommended_products)

# Print the recommended products
print(f"Recommended products for {product_name}:")
print(df[is_recommended]['product_name'])
# Out:
#   File "C:\Users\20100\AppData\Local\Temp\ipykernel_19988\1093132993.py", line 21
#     def recommend_products(product_name, n_recommendations=5):
#     ^
# SyntaxError: invalid syntax

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
from scipy.sparse import hstack  
#concatenate the tfidf_matrix and count_matrix horizontally using the hstack function from the scipy.sparse module ,it
#make sure that both matrices have the same number of columns

# Load the product data
# df = pd.read_csv("C:\\Users\\20100\\Desktop\\graduation project\\ML Model\\furniture_store - Copy_db.csv",
#                  usecols=["product_category","product_name","product_description"])
df = pd.read_csv("C:\\Users\\20100\\Desktop\\graduation project\\ML Model\\furniture_store - Copy_db.csv",
                 usecols=["product_category","product_name","product_description"])

# Define the product description and category/name vectors
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
count_vectorizer = CountVectorizer(stop_words='english')

product_descriptions = df['product_description']
product_categories = df['product_category']
product_names = df['product_name']

# Create the product description and category/name matrices
tfidf_matrix = tfidf_vectorizer.fit_transform(product_descriptions)
count_matrix = count_vectorizer.fit_transform(product_categories + ' ' + product_names)

# Combine the matrices
combined_similarity_matrix = cosine_similarity(hstack([tfidf_matrix, count_matrix]))



def recommend_products(product_name, n_recommendations=25):
    # Get the index of the product
    #####product_index = df[df['product_name'] == product_name].index[0]
    indices = pd.Series(df.index, index=df['product_name']).drop_duplicates()
    product_index = indices[product_name]
    # Get the similarity scores of all products with the given product
    product_similarities = list(enumerate(combined_similarity_matrix[product_index]))

    # Sort the products based on similarity scores
    product_similarities = sorted(product_similarities, key=lambda x: x[1], reverse=True)

    # Get the indices of the top-n most similar products (excluding the first one, which is the input product itself)
    top_n_indices = [i[0] for i in product_similarities[1:n_recommendations+1]]

    # Return the top-n most similar products
    return df.iloc[top_n_indices]
#Cell 5: Test the recommendation system

# Replace 'NORBERG' with the product name you want to get recommendations for
product_name = 'HOLMSUND'


# n_recommendations = 25
# recommended_products = recommend_products(product_name, n_recommendations)
# print(f"Top {n_recommendations} recommendations for {product_name}:")
# recommended_products

n_recommendations = 25
recommended_products = recommend_products(product_name, n_recommendations)
print(f"Top {n_recommendations} recommendations for {product_name}:")
if len(recommended_products) > 0:
    print(recommended_products)
else:
    print("No recommendations found.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19988\2076119144.py in <module>
#      57
#      58 n_recommendations = 25
# ---> 59 recommended_products = recommend_products(product_name, n_recommendations)
#      60 print(f"Top {n_recommendations} recommendations for {product_name}:")
#      61 if len(recommended_products) > 0:
#
# ~\AppData\Local\Temp\ipykernel_19988\2076119144.py in recommend_products(product_name, n_recommendations)
#      38
#      39     # Sort the products based on similarity scores
# ---> 40     product_similarities = sorted(product_similarities, key=lambda x: x[1], reverse=True)
#      41
#      42     # Get the indices of the top-n most similar products (excluding the first one, which is the input product itself)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# Parse the stringified features into their corresponding python objects
from ast import literal_eval

features = ['cast', 'crew', 'keywords', 'genres']
for feature in features:
    df2[feature] = df2[feature].apply(literal_eval)

# %%
# Function to convert all strings to lower case and strip names of spaces
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
# Apply clean_data function to your features.
features = ['cast', 'keywords', 'director', 'genres']

for feature in features:
    df2[feature] = df2[feature].apply(clean_data)

# %%
# We are now in a position to create our "metadata soup",
# which is a string that contains all the metadata that we want to feed to our vectorizer
# (namely actors, director and keywords).
def create_soup(x):
    return ' '.join(x['keywords']) + ' ' + ' '.join(x['cast']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])
df2['soup'] = df2.apply(create_soup, axis=1)

# %%
# The next steps are the same as what we did with our plot description based recommender.
# One important difference is that we use the CountVectorizer() instead of TF-IDF. 
# This is because we do not want to down-weight the presence of an actor/director 
# if he or she has acted or directed in relatively more movies. It doesn't make much intuitive sense.
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df2['soup'])

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset index of our main DataFrame and construct reverse mapping as before
df2 = df2.reset_index()
indices = pd.Series(df2.index, index=df2['title'])

# %%
# We can now reuse our get_recommendations() function by passing in the new cosine_sim2 matrix as your second argument.
get_recommendations('The Dark Knight Rises', cosine_sim2)

# %%
# We see that our recommender has been successful in capturing more information due to more metadata
# and has given us (arguably) better recommendations. 
# It is more likely that Marvels or DC comics fans will like the movies of the same production house.
# Therefore, to our features above we can add production_company . 
# We can also increase the weight of the director , by adding the feature multiple times in the soup.
